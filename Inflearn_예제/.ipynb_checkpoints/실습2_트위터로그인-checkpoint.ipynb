# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
chromedriver = './chromedriver.exe'
option = webdriver.ChromeOptions()

driver = webdriver.Chrome(chromedriver) 
driver.set_window_size(1920,1080)
driver.get('https://twitter.com/')

assert '트위터' in driver.title

# %%
ID_input = driver.find_element_by_css_selector('input[name="session[username_or_email]"]')

ID_input.send_keys('01025302359')

PW_input = driver.find_element_by_css_selector('input[name="session[password]"]')

PW_input.send_keys('ehlswkd1!')
PW_input.send_keys(Keys.ENTER)

# %%
text_list = driver.find_elements_by_css_selector('div[aria-label="Timeline: Your Home Timeline"]')

for text in text_list :
    print(text.text)
# Out:
# TensorFlow Retweeted
# Josh Gordon
# @random_forests
# ·
# Sep 27
# Two new tutorials and a guide to help you load and preprocess structured data (CSVs, etc):
#
# https://tensorflow.org/tutorials/load_data/csv…
#
# https://tensorflow.org/tutorials/structured_data/preprocessing_layers…
#
# https://tensorflow.org/guide/keras/preprocessing_layers…
# Load CSV data  |  TensorFlow Core
# tensorflow.org
# 5
# 66
# 286
# TensorFlow
# @TensorFlow
# ·
# Oct 10
#  Neural Structured Learning in TFX.
#
# In
# @gopalanarjun
# 's new blog, you'll learn how graph regularization can be implemented using custom TFX components and how adversarial learning can be deployed seamlessly with TFX.
#
# Read more ↓
# Neural Structured Learning in TFX
# blog.tensorflow.org
# 30
# 114
# TensorFlow
# @TensorFlow
# ·
# Oct 10
# We like the sound of that!
#
# #ToneTransfer mixes music and machine learning to unlock new sounds using your voice and more. Give it a try at http://g.co/tonetransfer
#
# #MadeWithTFJS
# ...
